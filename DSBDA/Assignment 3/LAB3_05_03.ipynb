# %%
import pandas as pd

# %%
data = pd.read_csv("IRIS.csv")
print(data.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
grouped = data.groupby("species")

# %%
summary = grouped.describe()
print(summary)
# Out:
#                 sepal_length                                              \
#                        count   mean       std  min    25%  50%  75%  max
# species
# Iris-setosa             50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# Iris-versicolor         50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# Iris-virginica          50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#                 sepal_width         ... petal_length      petal_width         \
#                       count   mean  ...          75%  max       count   mean
# species                             ...
# Iris-setosa            50.0  3.418  ...        1.575  1.9        50.0  0.244
# Iris-versicolor        50.0  2.770  ...        4.600  5.1        50.0  1.326
# Iris-virginica         50.0  2.974  ...        5.875  6.9        50.0  2.026
#
#
#                       std  min  25%  50%  75%  max
# species
# Iris-setosa      0.107210  0.1  0.2  0.2  0.3  0.6
# ...

# %%
setosa = data[data["species"] == "Iris-setosa"]["sepal_length"].tolist()
versicolor = data[data["species"] == "Iris-versicolor"]["sepal_length"].tolist()
virginica = data[data["species"] == "Iris-virginica"]["sepal_length"].tolist()

print("Setosa values:", setosa[:5])
print("Versicolor values:", versicolor[:5])
print("Virginica values:", virginica[:5])
# Out:
# Setosa values: [5.1, 4.9, 4.7, 4.6, 5.0]
# Versicolor values: [7.0, 6.4, 6.9, 5.5, 6.5]
# Virginica values: [6.3, 5.8, 7.1, 6.3, 6.5]

# %%
import pandas as pd

# Load dataset
data = pd.read_csv("IRIS.csv")

# Filter species
setosa = data[data['species'] == 'Iris-setosa']
versicolor = data[data['species'] == 'Iris-versicolor']
virginica = data[data['species'] == 'Iris-virginica']

# Function to print statistics
def show_stats(name, dataset):
    print("\nStatistics for", name)
    print(dataset.describe())

show_stats("Iris-setosa", setosa)
show_stats("Iris-versicolor", versicolor)
show_stats("Iris-virginica", virginica)
# Out:
# Statistics for Iris-setosa
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        5.00600     3.418000      1.464000      0.24400
# std         0.35249     0.381024      0.173511      0.10721
# min         4.30000     2.300000      1.000000      0.10000
# 25%         4.80000     3.125000      1.400000      0.20000
# 50%         5.00000     3.400000      1.500000      0.20000
# 75%         5.20000     3.675000      1.575000      0.30000
# max         5.80000     4.400000      1.900000      0.60000
#
# Statistics for Iris-versicolor
#        sepal_length  sepal_width  petal_length  petal_width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.600000     2.525000      4.000000     1.200000
# ...
